# %%
import pandas as pd
from ftpr.entities import Phase
from ftpr.visualization import PhaseVisualizer
import os

# %% [markdown]
# ### Set Variables

# %%
phases_dir = os.path.join('..', 'data', 'team_phases')
team = 'Manchester City'
phase_id = 105

# %% [markdown]
# ### Load The Phase

# %%
df = pd.read_csv(os.path.join(phases_dir, f'{team}.csv'))
print('Total phases:', len(df['phase_id'].unique()))
# Out:
# Total phases: 8024
# /var/folders/tv/_qfcls8d76jd1sp6y_8qsd700000gn/T/ipykernel_8316/3578949049.py:2: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'../data/team_phases/{team_name}.csv')
#    Unnamed: 0 carry_end_location dribble_outcome  \
# 0          14                NaN             NaN
# 1         919                NaN             NaN
# 2          15                NaN             NaN
# 3         920                NaN             NaN
# 4        2909                NaN             NaN
#
#                                      id  index      location  match_id  out  \
# 0  f5a217d2-0ba0-49bb-9854-0c26fe2060ae     28  [47.6, 44.4]   3754045  NaN
# 1  60ad5e93-2411-4cb0-a750-988d0067ecfd     29  [43.7, 50.5]   3754045  NaN
# 2  c13b671d-4bfa-4a85-8ba3-a7253ab0cc5a     30  [43.7, 50.5]   3754045  NaN
# 3  94b03a78-6f28-4fc4-85ea-fb346e86dbf1     32  [67.7, 54.9]   3754045  NaN
# 4  85cbd8ed-5355-4684-a2f3-90741b2c2504     34  [50.1, 59.6]   3754045  NaN
#
#    pass_angle pass_assisted_shot_id  ... shot_statsbomb_xg shot_type tactics  \
# 0    2.139644                   NaN  ...               NaN       NaN     NaN
# 1         NaN                   NaN  ...               NaN       NaN     NaN
# 2    0.268366                   NaN  ...               NaN       NaN     NaN
# 3         NaN                   NaN  ...               NaN       NaN     NaN
# 4         NaN                   NaN  ...               NaN       NaN     NaN
#
#               team team_id     timestamp           type foul_won_penalty  \
# 0  Manchester City      36  00:00:17.793           Pass              NaN
# 1  Manchester City      36  00:00:18.826  Ball Receipt*              NaN
# 2  Manchester City      36  00:00:18.828           Pass              NaN
# 3  Manchester City      36  00:00:21.201  Ball Receipt*              NaN
# 4  Manchester City      36  00:00:22.792  Ball Recovery              NaN
#
#   pass_goal_assist phase_id
# 0              NaN        0
# 1              NaN        0
# 2              NaN        0
# 3              NaN        0
# 4              NaN        1
#
# [5 rows x 40 columns]

# %%
df_phase = df[df['phase_id'] == phase_id]
df_phase.head()
# Out:
#      Unnamed: 0 carry_end_location dribble_outcome  \
# 819        2961                NaN             NaN
# 820        2058       [30.2, 66.5]             NaN
# 821         423                NaN             NaN
# 822        1309                NaN             NaN
# 823        2059       [34.8, 19.6]             NaN
#
#                                        id  index      location  match_id  out  \
# 819  219e0ac9-9da4-445f-ab5c-d65acca682c0   1479  [41.8, 72.8]   3754045  NaN
# 820  3b29cfc9-93c3-45a5-8a6a-25527c75fff4   1480  [41.8, 72.8]   3754045  NaN
# 821  0f172c2c-9a25-4795-9303-054eee628d57   1481  [30.2, 66.5]   3754045  NaN
# 822  64d95a3e-0da6-4a84-a881-a475a981be35   1482  [34.2, 21.3]   3754045  NaN
# 823  43e277ce-0143-49ca-a649-38213f6fa6ca   1483  [34.2, 21.3]   3754045  NaN
#
#      pass_angle pass_assisted_shot_id  ... shot_statsbomb_xg shot_type  \
# 819         NaN                   NaN  ...               NaN       NaN
# 820         NaN                   NaN  ...               NaN       NaN
# 821   -1.482531                   NaN  ...               NaN       NaN
# 822         NaN                   NaN  ...               NaN       NaN
# 823         NaN                   NaN  ...               NaN       NaN
#
#     tactics             team team_id     timestamp           type  \
# 819     NaN  Manchester City      36  00:35:44.223  Ball Recovery
# 820     NaN  Manchester City      36  00:35:44.223          Carry
# 821     NaN  Manchester City      36  00:35:45.738           Pass
# 822     NaN  Manchester City      36  00:35:47.708  Ball Receipt*
# 823     NaN  Manchester City      36  00:35:47.708          Carry
#
#     foul_won_penalty pass_goal_assist phase_id
# 819              NaN              NaN      105
# 820              NaN              NaN      105
# 821              NaN              NaN      105
# 822              NaN              NaN      105
# 823              NaN              NaN      105
#
# [5 rows x 40 columns]

# %%
phase = Phase(df_phase)
phase.get_summary()
# Out:
#           location pass_end_location carry_end_location           type  \
# 819   [41.8, 72.8]               NaN                NaN  Ball Recovery
# 820   [41.8, 72.8]               NaN       [30.2, 66.5]          Carry
# 821   [30.2, 66.5]      [34.2, 21.3]                NaN           Pass
# 822   [34.2, 21.3]               NaN                NaN  Ball Receipt*
# 823   [34.2, 21.3]               NaN       [34.8, 19.6]          Carry
# 824   [34.8, 19.6]      [44.9, 29.2]                NaN           Pass
# 825   [44.9, 29.2]               NaN                NaN  Ball Receipt*
# 826   [44.9, 29.2]               NaN       [45.7, 29.3]          Carry
# 827   [45.7, 29.3]      [48.7, 50.2]                NaN           Pass
# 828   [48.7, 50.2]               NaN                NaN  Ball Receipt*
# 829   [48.7, 50.2]               NaN       [51.9, 45.8]          Carry
# 830   [51.9, 45.8]      [49.4, 32.9]                NaN           Pass
# 831   [49.4, 32.9]               NaN                NaN  Ball Receipt*
# 832   [49.4, 32.9]               NaN       [48.0, 39.6]          Carry
# 833   [48.0, 39.6]      [44.8, 65.5]                NaN           Pass
# 834   [44.8, 65.5]               NaN                NaN  Ball Receipt*
# 835   [44.8, 65.5]               NaN       [49.0, 66.3]          Carry
# 836   [49.0, 66.3]      [66.6, 61.1]                NaN           Pass
# 837   [66.6, 61.1]               NaN                NaN  Ball Receipt*
# 838   [66.6, 60.5]      [61.9, 53.7]                NaN           Pass
# 839   [61.9, 53.7]               NaN                NaN  Ball Receipt*
# 840   [61.9, 53.7]               NaN       [61.9, 52.0]          Carry
# 841   [61.9, 52.0]      [66.6, 50.5]                NaN           Pass
# 842   [66.6, 50.5]               NaN                NaN  Ball Receipt*
# 843   [66.6, 50.5]               NaN       [66.6, 50.5]          Carry
# 844   [66.6, 50.5]      [79.5, 52.3]                NaN           Pass
# 845   [79.5, 52.3]               NaN                NaN  Ball Receipt*
# 846   [79.5, 52.3]               NaN       [77.0, 52.5]          Carry
# 847   [77.0, 52.5]      [74.1, 59.9]                NaN           Pass
# 848   [74.1, 59.9]               NaN                NaN  Ball Receipt*
# 849   [74.1, 59.9]               NaN       [74.2, 59.9]          Carry
# 850   [74.2, 59.9]      [62.8, 48.8]                NaN           Pass
# 851   [62.8, 48.8]               NaN                NaN  Ball Receipt*
# 852   [62.8, 48.8]               NaN       [62.6, 48.8]          Carry
# 853   [62.6, 48.8]      [66.5, 53.7]                NaN           Pass
# 854   [66.5, 53.7]               NaN                NaN  Ball Receipt*
# 855   [66.5, 53.7]               NaN       [74.1, 43.0]          Carry
# 856   [74.1, 43.0]      [71.0, 27.1]                NaN           Pass
# 857   [71.0, 27.1]               NaN                NaN  Ball Receipt*
# 858   [71.0, 27.1]               NaN       [72.1, 26.2]          Carry
# 859   [72.1, 26.2]       [91.8, 4.9]                NaN           Pass
# 860    [91.8, 4.9]               NaN                NaN  Ball Receipt*
# 861    [91.8, 4.9]               NaN        [98.6, 9.7]          Carry
# 862    [98.6, 9.7]     [112.9, 35.8]                NaN           Pass
# 863  [112.4, 38.0]               NaN                NaN  Ball Receipt*
#
#         timestamp
# 819  00:35:44.223
# 820  00:35:44.223
# 821  00:35:45.738
# 822  00:35:47.708
# 823  00:35:47.708
# 824  00:35:48.851
# 825  00:35:49.798
# 826  00:35:49.798
# 827  00:35:51.440
# 828  00:35:52.389
# 829  00:35:52.389
# 830  00:35:53.104
# 831  00:35:54.140
# 832  00:35:54.140
# 833  00:35:55.409
# 834  00:35:56.807
# 835  00:35:56.807
# 836  00:35:57.960
# 837  00:35:58.983
# 838  00:35:58.983
# 839  00:36:00.027
# 840  00:36:00.027
# 841  00:36:00.844
# 842  00:36:01.613
# 843  00:36:01.613
# 844  00:36:02.402
# 845  00:36:03.494
# 846  00:36:03.494
# 847  00:36:05.082
# 848  00:36:06.090
# 849  00:36:06.090
# 850  00:36:06.192
# 851  00:36:07.720
# 852  00:36:07.720
# 853  00:36:08.476
# 854  00:36:09.253
# 855  00:36:09.253
# 856  00:36:12.836
# 857  00:36:14.308
# 858  00:36:14.308
# 859  00:36:14.322
# 860  00:36:16.158
# 861  00:36:16.158
# 862  00:36:18.776
# 863  00:36:19.790

# %% [markdown]
# ### Filter Static Events

# %%
phase = phase.filter_static_events()
phase.get_summary()
# Out:
#           location pass_end_location carry_end_location           type  \
# 819   [41.8, 72.8]               NaN                NaN  Ball Recovery
# 820   [41.8, 72.8]               NaN       [30.2, 66.5]          Carry
# 821   [30.2, 66.5]      [34.2, 21.3]                NaN           Pass
# 823   [34.2, 21.3]               NaN       [34.8, 19.6]          Carry
# 824   [34.8, 19.6]      [44.9, 29.2]                NaN           Pass
# 826   [44.9, 29.2]               NaN       [45.7, 29.3]          Carry
# 827   [45.7, 29.3]      [48.7, 50.2]                NaN           Pass
# 829   [48.7, 50.2]               NaN       [51.9, 45.8]          Carry
# 830   [51.9, 45.8]      [49.4, 32.9]                NaN           Pass
# 832   [49.4, 32.9]               NaN       [48.0, 39.6]          Carry
# 833   [48.0, 39.6]      [44.8, 65.5]                NaN           Pass
# 835   [44.8, 65.5]               NaN       [49.0, 66.3]          Carry
# 836   [49.0, 66.3]      [66.6, 61.1]                NaN           Pass
# 837   [66.6, 61.1]               NaN                NaN  Ball Receipt*
# 838   [66.6, 60.5]      [61.9, 53.7]                NaN           Pass
# 840   [61.9, 53.7]               NaN       [61.9, 52.0]          Carry
# 841   [61.9, 52.0]      [66.6, 50.5]                NaN           Pass
# 844   [66.6, 50.5]      [79.5, 52.3]                NaN           Pass
# 846   [79.5, 52.3]               NaN       [77.0, 52.5]          Carry
# 847   [77.0, 52.5]      [74.1, 59.9]                NaN           Pass
# 849   [74.1, 59.9]               NaN       [74.2, 59.9]          Carry
# 850   [74.2, 59.9]      [62.8, 48.8]                NaN           Pass
# 852   [62.8, 48.8]               NaN       [62.6, 48.8]          Carry
# 853   [62.6, 48.8]      [66.5, 53.7]                NaN           Pass
# 855   [66.5, 53.7]               NaN       [74.1, 43.0]          Carry
# 856   [74.1, 43.0]      [71.0, 27.1]                NaN           Pass
# 858   [71.0, 27.1]               NaN       [72.1, 26.2]          Carry
# 859   [72.1, 26.2]       [91.8, 4.9]                NaN           Pass
# 861    [91.8, 4.9]               NaN        [98.6, 9.7]          Carry
# 862    [98.6, 9.7]     [112.9, 35.8]                NaN           Pass
# 863  [112.4, 38.0]               NaN                NaN  Ball Receipt*
#
#         timestamp
# 819  00:35:44.223
# 820  00:35:44.223
# 821  00:35:45.738
# 823  00:35:47.708
# 824  00:35:48.851
# 826  00:35:49.798
# 827  00:35:51.440
# 829  00:35:52.389
# 830  00:35:53.104
# 832  00:35:54.140
# 833  00:35:55.409
# 835  00:35:56.807
# 836  00:35:57.960
# 837  00:35:58.983
# 838  00:35:58.983
# 840  00:36:00.027
# 841  00:36:00.844
# 844  00:36:02.402
# 846  00:36:03.494
# 847  00:36:05.082
# 849  00:36:06.090
# 850  00:36:06.192
# 852  00:36:07.720
# 853  00:36:08.476
# 855  00:36:09.253
# 856  00:36:12.836
# 858  00:36:14.308
# 859  00:36:14.322
# 861  00:36:16.158
# 862  00:36:18.776
# 863  00:36:19.790

# %% [markdown]
# ### Visualize The Phase

# %%
visualizer = PhaseVisualizer(figsize=(16, 11))
events_config = {
    'Pass': {
        'color': '#00ffff'
    },
    'Carry': {
        'color': '#00aa00',
        'dashed': True
    },
    'Shot': {
        'color': '#aa0000'
    } 
}

location_columns = ['location', 'pass_end_location', 'carry_end_location', 'shot_end_location']
phase = phase.split_locations(location_columns)

fig, ax = visualizer.plot_phase(phase, events_config)
